# %%
#text = 'hello python world'

#Replace spaces with underscores in the string (e.g., "hello python world" → "hello_python_world").

#Split the modified string (e.g., "hello_python_world" → ['hello', 'python', 'world']).

#Print all two results

#Hint: Use string methods

text = 'hello python world'
text1 = text.replace(" ","_")
text2 = text1.split("_")
print(text1)
print(text2)
# Out:
# hello_python_world
# ['hello', 'python', 'world']

# %%
#1-

#text = 'hello python world'

#Replace spaces with underscores in the string (e.g., "hello python world" → "hello_python_world").

#Split the modified string (e.g., "hello_python_world" → ['hello', 'python', 'world']).

#Print all two results

text = 'hello python world'
text1 = text.replace(" ","_")
text2 = text1.split("_")
print(text1)
print(text2)
# Out:
# hello_python_world
# ['hello', 'python', 'world']

# %%
#2- You have a product code that follows the format "SKU-12345-XYZ".

#Find the first position of the dash (-).

#Count the number of dashes (-) in the product code.

#Remove the "SKU-" prefix and "-XYZ" suffix from the product code, Extract the numeric part 12345

#product_code = "SKU-12345-XYZ"

product_code = "SKU-12345-XYZ"
positionofthedashes = product_code.find("-")
print(positionofthedashes)
countofdashes = product_code.count("-")
print(countofdashes)
product_code1 = product_code.replace("SKU-","")
product_code2 = product_code1.replace("-XYZ","")
print(product_code2)
product_code3 = product_code[4:-4]
print(product_code3)
# Out:
# 3
# 2
# 12345
# 12345

# %%
#3- Convert a string to Title Case.

#text_1 = "hello world"

text = "hello world"
text1 = text.title()
text1
# Out:
# 'Hello World'

# %%
#4- Capitalize the first letter of a string.

#text_2 = "python programming"

text = "python programming"
text1 = text.capitalize()
text1
# Out:
# 'Python programming'

# %%
#5- Given the string below, write Python code to:0

#Convert the string so that each word starts with a capital letter

#Then swap the case of every letter in the resulting string

#Print the final result.

#text1 = "learning PYTHON is AWESOME"

text = "learning PYTHON is AWESOME"
text1 = text.title()
text2 = text1.swapcase()
print(text1)
text2
# Out:
# Learning Python Is Awesome
# 'lEARNING pYTHON iS aWESOME'

# %%
#6-Write Python code to check and print whether the string satisfies the following:

#Is alphanumeric?

#Is alphabetic only?

#text2 = "HelloWorld123"

text = "HelloWorld123"
text1 = text.isalnum()
text2 = text.isalpha()
text3 = text.isdigit()
print(text1)
print(text2)
print(text3)
# Out:
# True
# False
# False

# %%
# #7-

# #Write Python code to check and print whether the string satisfies the following:

# Is the string made up of digits only?

# Is the string all lowercase?

# text3 = "helloworld"

text = "helloworld"
text1 = text.isdigit()
text2 = text.islower()
print(text1)
print(text2)
# Out:
# False
# True

# %%
# 8-

# Write Python code to check and print whether the string satisfies the following:

# Is the string all uppercase?

# Is the string titlecased?

# text4 = 'Hi We Are Learning Python'
text = 'Hi We Are Learning Python'
text1 = text.isupper()
text2 = text.istitle()
print(text1)
print(text2)
# Out:
# False
# True

# %%
# 9-

# Write Python code to check and print whether the string:

# Starts with "data"

# Ends with ".csv"

# text5 = "data_report_2023.csv"

text = "data_report_2023.csv"
text1 = text.startswith("data")
text2 = text.endswith(".csv")
print(text1)
print(text2)
# Out:
# True
# True

# %%
# 10-

# Write Python code to:

# Count how many times "banana" appears in the string.

# fruit = "banana bandana banana"

fruit = "banana bandana banana"
fruitcount = fruit.count("banana")
fruitcount
# Out:
# 2
